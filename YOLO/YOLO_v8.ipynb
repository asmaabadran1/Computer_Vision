# %%
# !nvidia-smi
# Out:
# Fri May 12 20:00:49 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
! pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from ultralytics import YOLO
from IPython.display import display,Image

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/sample_data/walkingdog.jpeg'
# Out:
# Ultralytics YOLOv8.0.99 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/sample_data/walkingdog.jpeg: 448x640 2 persons, 1 dog, 72.8ms
# Speed: 3.1ms preprocess, 72.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict7

# %%
image="/content/runs/detect/predict6/walkingdog.jpeg"
Image(filename=image,height=500)

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/sample_data/intersection.jpeg'
# Out:
# Ultralytics YOLOv8.0.99 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/sample_data/intersection.jpeg: 384x640 1 bicycle, 5 cars, 2 stop signs, 76.8ms
# Speed: 2.4ms preprocess, 76.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict8

# %%
image="/content/runs/detect/predict8/intersection.jpeg"
Image(filename=image,height=500)

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/sample_data/jungle.jpeg'
# Out:
# Ultralytics YOLOv8.0.99 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/sample_data/jungle.jpeg: 544x640 1 bird, 1 bear, 118.9ms
# Speed: 12.8ms preprocess, 118.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict9

# %%
image="/content/runs/detect/predict9/jungle.jpeg"
Image(filename=image,height=500)

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/sample_data/traffic.jpeg'
# Out:
# Ultralytics YOLOv8.0.99 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/sample_data/traffic.jpeg: 448x640 1 person, 1 bicycle, 8 cars, 1 traffic light, 75.0ms
# Speed: 3.7ms preprocess, 75.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict10

# %%
image="/content/runs/detect/predict10/traffic.jpeg"
Image(filename=image,height=500)
